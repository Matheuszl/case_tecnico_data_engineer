-- %%
COMMENT ON TABLE workspace.lakehouse_panvel.silver_vendas IS
'Tabela fato contendo uma linha por venda realizada. Utilizada para análises de receita, faturamento, ticket médio, clientes fidelidade e formas de pagamento.';

COMMENT ON COLUMN workspace.lakehouse_panvel.silver_vendas.id_venda IS
'Identificador único da venda. Representa uma venda realizada por um cliente e é utilizado para relacionar esta tabela com a tabela gold_fato_itens_venda, que contém os produtos vendidos em cada venda.';

COMMENT ON COLUMN workspace.lakehouse_panvel.silver_vendas.id_filial IS
'Identificador da filial onde a venda foi realizada. Permite relacionar a venda às informações da loja, cidade, estado e regional.';

COMMENT ON COLUMN workspace.lakehouse_panvel.silver_vendas.data_venda IS
'Data em que a venda foi realizada. Utilizada para análises temporais como crescimento mensal, evolução anual e comparativos entre períodos.';

COMMENT ON COLUMN workspace.lakehouse_panvel.silver_vendas.quantidade_produtos IS
'Quantidade de produtos distintos presentes na venda. Cada produto é contabilizado apenas uma vez, independentemente da quantidade comprada.';

COMMENT ON COLUMN workspace.lakehouse_panvel.silver_vendas.quantidade_itens_produtos IS
'Quantidade total de unidades vendidas na venda, considerando a soma das quantidades de todos os produtos.';

COMMENT ON COLUMN workspace.lakehouse_panvel.silver_vendas.valor_bruto_venda IS
'Soma do valor bruto de todos os itens da venda antes da aplicação de descontos.';

COMMENT ON COLUMN workspace.lakehouse_panvel.silver_vendas.valor_desconto_venda IS
'Valor total de descontos aplicados aos itens da venda. Este valor reduz o valor bruto para obtenção do valor final da venda.';

COMMENT ON COLUMN workspace.lakehouse_panvel.silver_vendas.valor_total_venda IS
'Valor líquido final da venda, calculado pela diferença entre valor_bruto_venda e valor_desconto_venda. Esta é a métrica recomendada para análises de receita, faturamento e ticket médio.';

COMMENT ON COLUMN workspace.lakehouse_panvel.silver_vendas.id_cliente_fidelidade IS
'Identificador do cliente no programa de fidelidade. Será nulo quando a venda for realizada sem identificação de um cliente fidelizado.';

COMMENT ON COLUMN workspace.lakehouse_panvel.silver_vendas.flag_fidelidade IS
'Indica se a venda foi realizada por um cliente do programa de fidelidade. Valores possíveis: Sim ou Não. Recomenda-se utilizar esta coluna para análises comparativas entre clientes fidelizados e não fidelizados.';

COMMENT ON COLUMN workspace.lakehouse_panvel.silver_vendas.forma_pagamento IS
'Forma de pagamento utilizada na venda. Valores possíveis: Cartão Crédito, Cartão Débito, Convênio, Pix e Dinheiro.';

COMMENT ON COLUMN workspace.lakehouse_panvel.silver_vendas.status_venda IS
'Situação da venda. Valores possíveis: Concluída, Cancelada e Devolvida. Para análises de receita, faturamento, crescimento, evolução e ticket médio, considerar apenas registros com status_venda = ''Concluída''.';
