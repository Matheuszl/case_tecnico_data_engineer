-- %%
COMMENT ON TABLE workspace.lakehouse_panvel.silver_itens_venda IS
'Tabela fato contendo uma linha por item vendido. Cada registro representa um produto pertencente a uma venda. Utilizada para análises de produtos, categorias, quantidade vendida, descontos por item e participação de produtos nas vendas.';

COMMENT ON COLUMN workspace.lakehouse_panvel.silver_itens_venda.id_venda IS
'Identificador da venda à qual o item pertence. Utilizado para relacionar esta tabela com a tabela gold_fato_vendas, que contém as informações consolidadas da venda.';

COMMENT ON COLUMN workspace.lakehouse_panvel.silver_itens_venda.id_item_venda IS
'Identificador único do item da venda. Cada registro representa um produto comercializado dentro de uma venda.';

COMMENT ON COLUMN workspace.lakehouse_panvel.silver_itens_venda.id_filial IS
'Identificador da filial onde a venda foi realizada. Permite análises de produtos por loja, cidade, estado e regional.';

COMMENT ON COLUMN workspace.lakehouse_panvel.silver_itens_venda.id_produto IS
'Identificador do produto vendido. Utilizado para relacionar o item à dimensão de produtos.';

COMMENT ON COLUMN workspace.lakehouse_panvel.silver_itens_venda.quantidade IS
'Quantidade de unidades vendidas deste produto na venda.';

COMMENT ON COLUMN workspace.lakehouse_panvel.silver_itens_venda.valor_unitario IS
'Valor unitário do produto no momento da venda, antes da aplicação de descontos.';

COMMENT ON COLUMN workspace.lakehouse_panvel.silver_itens_venda.valor_bruto_item IS
'Valor bruto do item, calculado pela multiplicação da quantidade vendida pelo valor unitário do produto.';

COMMENT ON COLUMN workspace.lakehouse_panvel.silver_itens_venda.valor_desconto_item IS
'Valor de desconto aplicado ao item vendido. Este valor reduz o valor bruto do item para obtenção do valor final.';

COMMENT ON COLUMN workspace.lakehouse_panvel.silver_itens_venda.valor_final_item IS
'Valor líquido final do item após a aplicação dos descontos, calculado pela diferença entre valor_bruto_item e valor_desconto_item.';
