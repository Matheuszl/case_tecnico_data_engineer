-- %%
COMMENT ON TABLE workspace.lakehouse_panvel.silver_produtos IS
'Tabela dimensão contendo informações cadastrais dos produtos comercializados pela rede. Utilizada para análises de vendas por produto, categoria, marca própria e características dos itens.';

COMMENT ON COLUMN workspace.lakehouse_panvel.silver_produtos.id_produto IS
'Identificador único do produto. Chave utilizada para relacionar os itens vendidos ao cadastro de produtos.';

COMMENT ON COLUMN workspace.lakehouse_panvel.silver_produtos.sku IS
'Código SKU utilizado para identificação comercial e logística do produto.';

COMMENT ON COLUMN workspace.lakehouse_panvel.silver_produtos.nome_produto IS
'Nome comercial descritivo do produto utilizado nas vendas, exemplo: Omeprazol 20mg';

COMMENT ON COLUMN workspace.lakehouse_panvel.silver_produtos.nome_categoria IS
'Categoria comercial do produto, utilizada para agrupamentos e análises por segmento de venda.';

COMMENT ON COLUMN workspace.lakehouse_panvel.silver_produtos.tipo_produto IS
'Classificação do produto conforme sua natureza. Sendo os tipos disponivel: Similar, Referencia, Generico e Nao Medicamento';

COMMENT ON COLUMN workspace.lakehouse_panvel.silver_produtos.controlado IS
'Indica se o produto é classificado como medicamento controlado. Valores possíveis: true ou false.';

COMMENT ON COLUMN workspace.lakehouse_panvel.silver_produtos.preco_tabela_atual IS
'Preço de tabela vigente do produto no momento da carga dos dados. Utilizado apenas como referência comercial e não representa necessariamente o preço efetivamente praticado na venda.';

COMMENT ON COLUMN workspace.lakehouse_panvel.silver_produtos.tipo_categoria IS
'Classificação para distinguir produtos de marca própria da rede Panvel ou de marcas de outras redes. Valores disponiveis: Rede e Própria';
