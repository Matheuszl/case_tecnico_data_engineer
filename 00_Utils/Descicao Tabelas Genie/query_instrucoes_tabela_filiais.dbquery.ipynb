-- %%
COMMENT ON TABLE workspace.lakehouse_panvel.bronze_filiais IS
'Tabela dimensão contendo informações cadastrais das filiais da rede Panvel. Utilizada para segmentação de indicadores por loja, cidade, estado, regional e tipo de operação.';

COMMENT ON COLUMN workspace.lakehouse_panvel.bronze_filiais.id_filial IS
'Identificador único da filial. Chave utilizada para relacionar as vendas à loja onde foram realizadas.';

COMMENT ON COLUMN workspace.lakehouse_panvel.bronze_filiais.nome_filial IS
'Nome completo da filial utilizado para identificação da loja nas análises e consultas em linguagem natural.';

COMMENT ON COLUMN workspace.lakehouse_panvel.bronze_filiais.uf IS
'Unidade Federativa (estado) onde a filial está localizada. Utilizada para análises geográficas.';

COMMENT ON COLUMN workspace.lakehouse_panvel.bronze_filiais.cidade IS
'Município onde a filial está localizada. Utilizado para análises por cidade.';

COMMENT ON COLUMN workspace.lakehouse_panvel.bronze_filiais.regional IS
'Unidade Regional administrativa responsável pela gestão da filial. Utilizada para consolidação de indicadores por Regional.';

COMMENT ON COLUMN workspace.lakehouse_panvel.bronze_filiais.tipo_loja IS
'Classificação da loja conforme seu modelo de operação. Valores possíveis: Rua, Shopping e Drive-thru.';

COMMENT ON COLUMN workspace.lakehouse_panvel.bronze_filiais.status IS
'Situação operacional da filial. Indica se a loja está em funcionamento com status "Ativa" ou inativa com status "Inativa".';

COMMENT ON COLUMN workspace.lakehouse_panvel.bronze_filiais.data_abertura IS
'Data de inauguração da filial. Pode ser utilizada para análises de crescimento da rede e tempo de operação das lojas.';
